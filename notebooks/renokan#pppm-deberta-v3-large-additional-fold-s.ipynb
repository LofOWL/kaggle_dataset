# %% [markdown]
# ### If this notebook is helpful, please upvote [the original version](https://www.kaggle.com/code/leehann/inference-bert-for-uspatents)! (score: 0.8392)

# %% [markdown]
# # 1. Import & Set & Def & Load

# %%
import os
import pandas as pd
import numpy as np

from tqdm import tqdm

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from transformers import AutoModelForSequenceClassification, AutoTokenizer, AutoConfig, AutoModel

from sklearn.preprocessing import MinMaxScaler

# %%
class CFG_DEB_SIMPLE:
    input_path = '../input/us-patent-phrase-to-phrase-matching/'
    model_path = '../input/deberta-v3-large/deberta-v3-large'
    batch_size = 24
    num_workers = 2
    num_fold = 4
    max_input_length = 130

# %%
class TestDataset(Dataset):
    def __init__(self, df, tokenizer, max_input_length):
        self.text = df['text'].values.astype(str)
        self.tokenizer = tokenizer
        self.max_input_length = max_input_length
        
    def __len__(self):
        return len(self.text)

    def __getitem__(self, item):
        inputs = self.text[item]
        
        inputs = self.tokenizer(inputs,
                    max_length=self.max_input_length,
                    padding='max_length',
                    truncation=True)
        
        return torch.as_tensor(inputs['input_ids'], dtype=torch.long), \
               torch.as_tensor(inputs['token_type_ids'], dtype=torch.long), \
               torch.as_tensor(inputs['attention_mask'], dtype=torch.long)
    
    
class Custom_Bert_Simple(nn.Module):
    def __init__(self, model_path):
        super().__init__()
        
        config = AutoConfig.from_pretrained(model_path)
        config.num_labels = 1
        self.base = AutoModelForSequenceClassification.from_config(config=config)
        dim = config.hidden_size
        self.dropout = nn.Dropout(p=0)
        self.cls = nn.Linear(dim,1)
        
    def forward(self, input_ids, attention_mask, token_type_ids, labels=None):
        base_output = self.base(input_ids=input_ids,
                                attention_mask=attention_mask,
                                token_type_ids=token_type_ids
        )

        return base_output[0]

# %%
def valid_fn(valid_loader, model, device):
    model.eval()
    preds = []
    labels = []
    
    for step, batch in enumerate(valid_loader):
        input_ids, token_type_ids, attention_mask = [i.to(device) for i in batch]
    
        with torch.no_grad():
            y_preds = model(input_ids, attention_mask, token_type_ids)
        
        preds.append(y_preds.to('cpu').numpy())
    
    predictions = np.concatenate(preds)
    
    return predictions


min_max_scaler = MinMaxScaler()

def upd_outputs(data, is_trim=True, is_minmax=True, is_reshape=True):
    """\o/"""
    if is_trim == True:
        data = np.where(data <=0, 0, data)
        data = np.where(data >=1, 1, data)

    if is_minmax ==True:
        data = min_max_scaler.fit_transform(data)
    
    if is_reshape == True:
        data = data.reshape(-1)
        
    return data

# %%
test_df = pd.read_csv(f"{CFG_DEB_SIMPLE.input_path}test.csv")
titles = pd.read_csv('../input/cpc-codes/titles.csv')
test_df = test_df.merge(titles, left_on='context', right_on='code')

cpc_texts = torch.load("../input/folds-dump-the-two-paths-fix/cpc_texts.pth")

test_df['context_text'] = test_df['context'].map(cpc_texts)
test_df['text'] = test_df['anchor'] + '[SEP]' + test_df['target'] + '[SEP]'  + test_df['context_text']
test_df['text'] = test_df['text'].apply(str.lower)

test_df.head()
# Out:
#                  id             anchor                         target context  \
# 0  4112d61851461f60           opc drum  inorganic photoconductor drum     G02
# 1  5203a36c501f1b7c  generate in layer              generate by layer     G02
# 2  7aa5908a77a7ec24         el display                   illumination     G02
# 3  09e418c93a776564    adjust gas flow              altering gas flow     F23
# 4  36baf228038e314b     lower trunnion                 lower locating     B60
#
#   code                                       title section  class subclass  \
# 0  G02                                      OPTICS       G    2.0      NaN
# 1  G02                                      OPTICS       G    2.0      NaN
# 2  G02                                      OPTICS       G    2.0      NaN
# 3  F23  COMBUSTION APPARATUS; COMBUSTION PROCESSES       F   23.0      NaN
# 4  B60                         VEHICLES IN GENERAL       B   60.0      NaN
#
#    group  main_group                                       context_text  \
# 0    NaN         NaN                                    PHYSICS. OPTICS
# 1    NaN         NaN                                    PHYSICS. OPTICS
# 2    NaN         NaN                                    PHYSICS. OPTICS
# 3    NaN         NaN  MECHANICAL ENGINEERING; LIGHTING; HEATING; WEA...
# 4    NaN         NaN  PERFORMING OPERATIONS; TRANSPORTING. VEHICLES ...
#
#                                                 text
# 0  opc drum[sep]inorganic photoconductor drum[sep...
# 1  generate in layer[sep]generate by layer[sep]ph...
# 2    el display[sep]illumination[sep]physics. optics
# 3  adjust gas flow[sep]altering gas flow[sep]mech...
# 4  lower trunnion[sep]lower locating[sep]performi...

# %% [markdown]
# # 2. Extract & Update Predictions

# %%
tokenizer_deberta_v3 = AutoTokenizer.from_pretrained(CFG_DEB_SIMPLE.model_path)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
predictions = []

te_dataset = TestDataset(test_df, tokenizer_deberta_v3, CFG_DEB_SIMPLE.max_input_length)
te_dataloader = DataLoader(te_dataset,
                              batch_size=CFG_DEB_SIMPLE.batch_size, shuffle=False,
                              num_workers=CFG_DEB_SIMPLE.num_workers,
                              pin_memory=True, drop_last=False)

deberta_simple_path = "../input/us-patent-deberta-simple/microsoft_deberta-v3-large"

for fold in tqdm(range(CFG_DEB_SIMPLE.num_fold)):
    fold_path = f"{deberta_simple_path}_best{fold}.pth"
    
    model = Custom_Bert_Simple(CFG_DEB_SIMPLE.model_path)
    model.load_state_dict(torch.load(fold_path)['model'])
    model.to('cuda')
    
    prediction = valid_fn(te_dataloader, model, 'cuda')
    
    predictions.append(prediction)
# Out:
# 100%|██████████| 4/4 [01:52<00:00, 28.12s/it]

# %%
print("folds:", len(predictions))
print("rows: ", len(predictions[0]))
print("score:", predictions[0][0])
# Out:
# folds: 4
# rows:  36
# score: [0.5036294]

# %%
n_predictions = 14

# %%
# first fold
predictions[0][:n_predictions]
# Out:
# array([[ 0.5036294 ],
#        [ 0.832283  ],
#        [ 0.35078326],
#        [ 0.4791839 ],
#        [ 0.49305084],
#        [ 0.5206834 ],
#        [ 0.2301636 ],
#        [ 0.4067986 ],
#        [ 0.27013338],
#        [ 0.5016197 ],
#        [ 0.516191  ],
#        [-0.02492346],
#        [ 0.1932471 ],
#        [ 0.93988395]], dtype=float32)

# %%
# print(*upd_outputs(predictions[0], is_trim=False)[:n_predictions])
# print(*upd_outputs(predictions[0], is_minmax=False)[:n_predictions])

# %%
# np.where(x<=0, 0, x) .. >> min_max.fit_transform(x) >> x.reshape(-1)
upd_predictions = [upd_outputs(x, is_trim=False) for x in predictions]

# %%
print(*upd_predictions[0][:n_predictions])
# Out:
# 0.5510465 0.8892669 0.3937512 0.52588946 0.54016006 0.56859696 0.26962045 0.4513971 0.3107537 0.5489783 0.5639738 0.0071080867 0.23162934 0.99999994

# %% [markdown]
# # 3. Additional & Final Predictions

# %%
origin_predictions = upd_predictions.copy()  # 5. Visualization

# %%
# === add np.median ===
add_preds = []
for x in zip(*upd_predictions):
    add_preds.append(np.median(x, axis=0))
    
upd_predictions.append(add_preds)

# %%
# === add np.mean ===
add_preds = []
for x in zip(*upd_predictions):
    add_preds.append(np.mean(x, axis=0))
    
upd_predictions.append(add_preds)

# %%
final_predictions = np.mean(upd_predictions, axis=0)

# %%
print(*final_predictions[:n_predictions])
# Out:
# 0.31270644 0.8849662 0.2845092 0.59676236 0.5130505 0.60881376 0.28154138 0.09131225 0.2716439 0.4976574 0.46910086 0.0035888723 0.2536781 0.9989567

# %% [markdown]
# # 4. Submission

# %%
submission = pd.DataFrame({
    'id': test_df['id'],
    'score': final_predictions,
})

submission.head(14)
# Out:
#                   id     score
# 0   4112d61851461f60  0.312706
# 1   5203a36c501f1b7c  0.884966
# 2   7aa5908a77a7ec24  0.284509
# 3   09e418c93a776564  0.596762
# 4   36baf228038e314b  0.513050
# 5   b892011ab2e2cabc  0.608814
# 6   1f37ead645e7f0c8  0.281541
# 7   71a5b6ad068d531f  0.091312
# 8   16ae4b99d3601e60  0.271644
# 9   474c874d0c07bd21  0.497657
# 10  442c114ed5c4e3c9  0.469101
# 11  b8ae62ea5e1d8bdb  0.003589
# 12  faaddaf8fcba8a3f  0.253678
# 13  ae0262c02566d2ce  0.998957

# %%
# ==== Baseline ====
# 0	4112d61851461f60	0.326429
# 1	5203a36c501f1b7c	0.874251
# 2	7aa5908a77a7ec24	0.289511
# 3	09e418c93a776564	0.600432
# 4	36baf228038e314b	0.514209
# 5	b892011ab2e2cabc	0.607818
# 6	1f37ead645e7f0c8	0.288515
# 7	71a5b6ad068d531f	0.113767
# 8	16ae4b99d3601e60	0.273690
# 9	474c874d0c07bd21	0.499560

# %%
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# # 5. Visualization origin_predictions

# %%
import seaborn as sns
cm = sns.light_palette('green', as_cmap=True)
props_param = "color:white; font-weight:bold; background-color:green;"
pd.set_option('display.precision', 10)

# %%
df = pd.DataFrame(origin_predictions).T.head(15)
df = df.rename_axis(columns='folds', index='rows')

df.style.background_gradient(cmap=cm, axis=1)
# Out:
# <style type="text/css">
# #T_6813e_row0_col0, #T_6813e_row1_col1, #T_6813e_row2_col0, #T_6813e_row3_col1, #T_6813e_row4_col0, #T_6813e_row5_col2, #T_6813e_row6_col1, #T_6813e_row7_col0, #T_6813e_row8_col0, #T_6813e_row9_col0, #T_6813e_row10_col0, #T_6813e_row11_col0, #T_6813e_row12_col2, #T_6813e_row13_col0, #T_6813e_row13_col2, #T_6813e_row13_col3, #T_6813e_row14_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_6813e_row0_col1 {
#   background-color: #e4f0e4;
#   color: #000000;
# }
# #T_6813e_row0_col2, #T_6813e_row1_col3, #T_6813e_row2_col2, #T_6813e_row3_col2, #T_6813e_row4_col1, #T_6813e_row5_col0, #T_6813e_row6_col2, #T_6813e_row7_col1, #T_6813e_row7_col2, #T_6813e_row7_col3, #T_6813e_row8_col2, #T_6813e_row9_col3, #T_6813e_row10_col2, #T_6813e_row11_col1, #T_6813e_row12_col0, #T_6813e_row13_col1, #T_6813e_row14_col2 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_6813e_row0_col3 {
#   background-color: #d6e9d6;
#   color: #000000;
# }
# #T_6813e_row1_col0 {
#   background-color: #49a449;
#   color: #f1f1f1;
# }
# #T_6813e_row1_col2 {
#   background-color: #158a15;
#   color: #f1f1f1;
# }
# #T_6813e_row2_col1 {
#   background-color: #ddecdd;
#   color: #000000;
# }
# #T_6813e_row2_col3 {
#   background-color: #a3d0a3;
#   color: #000000;
# }
# #T_6813e_row3_col0 {
#   background-color: #c3e0c3;
#   color: #000000;
# }
# #T_6813e_row3_col3 {
#   background-color: #65b265;
#   color: #f1f1f1;
# }
# #T_6813e_row4_col2 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_6813e_row4_col3 {
#   background-color: #9dcd9d;
#   color: #000000;
# }
# #T_6813e_row5_col1 {
#   background-color: #188c18;
#   color: #f1f1f1;
# }
# #T_6813e_row5_col3 {
#   background-color: #8ec58e;
#   color: #000000;
# }
# #T_6813e_row6_col0 {
#   background-color: #b4d8b4;
#   color: #000000;
# }
# #T_6813e_row6_col3 {
#   background-color: #d9ead9;
#   color: #000000;
# }
# #T_6813e_row8_col1 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_6813e_row8_col3 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_6813e_row9_col1 {
#   background-color: #83c083;
#   color: #000000;
# }
# #T_6813e_row9_col2 {
#   background-color: #d8ead8;
#   color: #000000;
# }
# #T_6813e_row10_col1 {
#   background-color: #269226;
#   color: #f1f1f1;
# }
# #T_6813e_row10_col3 {
#   background-color: #349a34;
#   color: #f1f1f1;
# }
# #T_6813e_row11_col2 {
#   background-color: #0c860c;
#   color: #f1f1f1;
# }
# #T_6813e_row11_col3 {
#   background-color: #e2efe2;
#   color: #000000;
# }
# #T_6813e_row12_col1 {
#   background-color: #48a348;
#   color: #f1f1f1;
# }
# #T_6813e_row12_col3 {
#   background-color: #b1d7b1;
#   color: #000000;
# }
# #T_6813e_row14_col1 {
#   background-color: #4ca54c;
#   color: #f1f1f1;
# }
# #T_6813e_row14_col3 {
#   background-color: #c4e0c4;
#   color: #000000;
# }
# </style>
# <table id="T_6813e_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >folds</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >rows</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6813e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6813e_row0_col0" class="data row0 col0" >0.5510464907</td>
#       <td id="T_6813e_row0_col1" class="data row0 col1" >0.2486642748</td>
#       <td id="T_6813e_row0_col2" class="data row0 col2" >0.2390424758</td>
#       <td id="T_6813e_row0_col3" class="data row0 col3" >0.2669645548</td>
#     </tr>
#     <tr>
#       <th id="T_6813e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6813e_row1_col0" class="data row1 col0" >0.8892669082</td>
#       <td id="T_6813e_row1_col1" class="data row1 col1" >1.0000000000</td>
#       <td id="T_6813e_row1_col2" class="data row1 col2" >0.9663894773</td>
#       <td id="T_6813e_row1_col3" class="data row1 col3" >0.6413460970</td>
#     </tr>
#     <tr>
#       <th id="T_6813e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6813e_row2_col0" class="data row2 col0" >0.3937512040</td>
#       <td id="T_6813e_row2_col1" class="data row2 col1" >0.2450732291</td>
#       <td id="T_6813e_row2_col2" class="data row2 col2" >0.2352896780</td>
#       <td id="T_6813e_row2_col3" class="data row2 col3" >0.2839302421</td>
#     </tr>
#     <tr>
#       <th id="T_6813e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6813e_row3_col0" class="data row3 col0" >0.5258894563</td>
#       <td id="T_6813e_row3_col1" class="data row3 col1" >0.7600160241</td>
#       <td id="T_6813e_row3_col2" class="data row3 col2" >0.4775429666</td>
#       <td id="T_6813e_row3_col3" class="data row3 col3" >0.6382790804</td>
#     </tr>
#     <tr>
#       <th id="T_6813e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6813e_row4_col0" class="data row4 col0" >0.5401600599</td>
#       <td id="T_6813e_row4_col1" class="data row4 col1" >0.4998472333</td>
#       <td id="T_6813e_row4_col2" class="data row4 col2" >0.5037006736</td>
#       <td id="T_6813e_row4_col3" class="data row4 col3" >0.5131292939</td>
#     </tr>
#     <tr>
#       <th id="T_6813e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6813e_row5_col0" class="data row5 col0" >0.5685969591</td>
#       <td id="T_6813e_row5_col1" class="data row5 col1" >0.6299690008</td>
#       <td id="T_6813e_row5_col2" class="data row5 col2" >0.6370874643</td>
#       <td id="T_6813e_row5_col3" class="data row5 col3" >0.5956205130</td>
#     </tr>
#     <tr>
#       <th id="T_6813e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6813e_row6_col0" class="data row6 col0" >0.2696204484</td>
#       <td id="T_6813e_row6_col1" class="data row6 col1" >0.4241000116</td>
#       <td id="T_6813e_row6_col2" class="data row6 col2" >0.2226627618</td>
#       <td id="T_6813e_row6_col3" class="data row6 col3" >0.2376757860</td>
#     </tr>
#     <tr>
#       <th id="T_6813e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6813e_row7_col0" class="data row7 col0" >0.4513970912</td>
#       <td id="T_6813e_row7_col1" class="data row7 col1" >0.0021326696</td>
#       <td id="T_6813e_row7_col2" class="data row7 col2" >0.0006830087</td>
#       <td id="T_6813e_row7_col3" class="data row7 col3" >0.0008547530</td>
#     </tr>
#     <tr>
#       <th id="T_6813e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6813e_row8_col0" class="data row8 col0" >0.3107537031</td>
#       <td id="T_6813e_row8_col1" class="data row8 col1" >0.2583637238</td>
#       <td id="T_6813e_row8_col2" class="data row8 col2" >0.2570839226</td>
#       <td id="T_6813e_row8_col3" class="data row8 col3" >0.2685575187</td>
#     </tr>
#     <tr>
#       <th id="T_6813e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6813e_row9_col0" class="data row9 col0" >0.5489783287</td>
#       <td id="T_6813e_row9_col1" class="data row9 col1" >0.5046707392</td>
#       <td id="T_6813e_row9_col2" class="data row9 col2" >0.4754208326</td>
#       <td id="T_6813e_row9_col3" class="data row9 col3" >0.4691711664</td>
#     </tr>
#     <tr>
#       <th id="T_6813e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6813e_row10_col0" class="data row10 col0" >0.5639737844</td>
#       <td id="T_6813e_row10_col1" class="data row10 col1" >0.5154461265</td>
#       <td id="T_6813e_row10_col2" class="data row10 col2" >0.2642332017</td>
#       <td id="T_6813e_row10_col3" class="data row10 col3" >0.4960854053</td>
#     </tr>
#     <tr>
#       <th id="T_6813e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6813e_row11_col0" class="data row11 col0" >0.0071080867</td>
#       <td id="T_6813e_row11_col1" class="data row11 col1" >0.0001263511</td>
#       <td id="T_6813e_row11_col2" class="data row11 col2" >0.0067444686</td>
#       <td id="T_6813e_row11_col3" class="data row11 col3" >0.0003954805</td>
#     </tr>
#     <tr>
#       <th id="T_6813e_level0_row12

# %%
df.style.highlight_quantile(q_left=0.75, axis=1, color='green')
# Out:
# <style type="text/css">
# #T_75a47_row0_col0, #T_75a47_row1_col1, #T_75a47_row2_col0, #T_75a47_row3_col1, #T_75a47_row4_col0, #T_75a47_row5_col2, #T_75a47_row6_col1, #T_75a47_row7_col0, #T_75a47_row8_col0, #T_75a47_row9_col0, #T_75a47_row10_col0, #T_75a47_row11_col0, #T_75a47_row12_col2, #T_75a47_row13_col2, #T_75a47_row13_col3, #T_75a47_row14_col0 {
#   background-color: green;
# }
# </style>
# <table id="T_75a47_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >folds</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >rows</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75a47_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75a47_row0_col0" class="data row0 col0" >0.5510464907</td>
#       <td id="T_75a47_row0_col1" class="data row0 col1" >0.2486642748</td>
#       <td id="T_75a47_row0_col2" class="data row0 col2" >0.2390424758</td>
#       <td id="T_75a47_row0_col3" class="data row0 col3" >0.2669645548</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75a47_row1_col0" class="data row1 col0" >0.8892669082</td>
#       <td id="T_75a47_row1_col1" class="data row1 col1" >1.0000000000</td>
#       <td id="T_75a47_row1_col2" class="data row1 col2" >0.9663894773</td>
#       <td id="T_75a47_row1_col3" class="data row1 col3" >0.6413460970</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75a47_row2_col0" class="data row2 col0" >0.3937512040</td>
#       <td id="T_75a47_row2_col1" class="data row2 col1" >0.2450732291</td>
#       <td id="T_75a47_row2_col2" class="data row2 col2" >0.2352896780</td>
#       <td id="T_75a47_row2_col3" class="data row2 col3" >0.2839302421</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_75a47_row3_col0" class="data row3 col0" >0.5258894563</td>
#       <td id="T_75a47_row3_col1" class="data row3 col1" >0.7600160241</td>
#       <td id="T_75a47_row3_col2" class="data row3 col2" >0.4775429666</td>
#       <td id="T_75a47_row3_col3" class="data row3 col3" >0.6382790804</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_75a47_row4_col0" class="data row4 col0" >0.5401600599</td>
#       <td id="T_75a47_row4_col1" class="data row4 col1" >0.4998472333</td>
#       <td id="T_75a47_row4_col2" class="data row4 col2" >0.5037006736</td>
#       <td id="T_75a47_row4_col3" class="data row4 col3" >0.5131292939</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_75a47_row5_col0" class="data row5 col0" >0.5685969591</td>
#       <td id="T_75a47_row5_col1" class="data row5 col1" >0.6299690008</td>
#       <td id="T_75a47_row5_col2" class="data row5 col2" >0.6370874643</td>
#       <td id="T_75a47_row5_col3" class="data row5 col3" >0.5956205130</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_75a47_row6_col0" class="data row6 col0" >0.2696204484</td>
#       <td id="T_75a47_row6_col1" class="data row6 col1" >0.4241000116</td>
#       <td id="T_75a47_row6_col2" class="data row6 col2" >0.2226627618</td>
#       <td id="T_75a47_row6_col3" class="data row6 col3" >0.2376757860</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_75a47_row7_col0" class="data row7 col0" >0.4513970912</td>
#       <td id="T_75a47_row7_col1" class="data row7 col1" >0.0021326696</td>
#       <td id="T_75a47_row7_col2" class="data row7 col2" >0.0006830087</td>
#       <td id="T_75a47_row7_col3" class="data row7 col3" >0.0008547530</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_75a47_row8_col0" class="data row8 col0" >0.3107537031</td>
#       <td id="T_75a47_row8_col1" class="data row8 col1" >0.2583637238</td>
#       <td id="T_75a47_row8_col2" class="data row8 col2" >0.2570839226</td>
#       <td id="T_75a47_row8_col3" class="data row8 col3" >0.2685575187</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_75a47_row9_col0" class="data row9 col0" >0.5489783287</td>
#       <td id="T_75a47_row9_col1" class="data row9 col1" >0.5046707392</td>
#       <td id="T_75a47_row9_col2" class="data row9 col2" >0.4754208326</td>
#       <td id="T_75a47_row9_col3" class="data row9 col3" >0.4691711664</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_75a47_row10_col0" class="data row10 col0" >0.5639737844</td>
#       <td id="T_75a47_row10_col1" class="data row10 col1" >0.5154461265</td>
#       <td id="T_75a47_row10_col2" class="data row10 col2" >0.2642332017</td>
#       <td id="T_75a47_row10_col3" class="data row10 col3" >0.4960854053</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_75a47_row11_col0" class="data row11 col0" >0.0071080867</td>
#       <td id="T_75a47_row11_col1" class="data row11 col1" >0.0001263511</td>
#       <td id="T_75a47_row11_col2" class="data row11 col2" >0.0067444686</td>
#       <td id="T_75a47_row11_col3" class="data row11 col3" >0.0003954805</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_75a47_row12_col0" class="data row12 col0" >0.2316293418</td>
#       <td id="T_75a47_row12_col1" class="data row12 col1" >0.2633186281</td>
#       <td id="T_75a47_row12_col2" class="data row12 col2" >0.2772911787</td>
#       <td id="T_75a47_row12_col3" class="data row12 col3" >0.2429948151</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_75a47_row13_col0" class="data row13 col0" >0.9999999404</td>
#       <td id="T_75a47_row13_col1" class="data row13 col1" >0.9947832227</td>
#       <td id="T_75a47_row13_col2" class="data row13 col2" >1.0000000000</td>
#       <td id="T_75a47_row13_col3" class="data row13 col3" >1.0000000000</td>
#     </tr>
#     <tr>
#       <th id="T_75a47_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_75a47_row14_col0" class="data row14 col0" >0.2610547543</td>
#       <td id="T_75a47_row14_col1" class="data row14 col1" >0.2556003928</td>
#       <td id="T_75a47_row14_col2" class="data row14 col2" >0.2442699522</td>
#       <td id="T_75a47_row14_col3" class="data row14 col3" >0.2470455021</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.assign(mean=lambda x: x.mean(axis=1)) \
    .style.highlight_max(axis=1, props=props_param)
# Out:
# <style type="text/css">
# #T_47e96_row0_col0, #T_47e96_row1_col1, #T_47e96_row2_col0, #T_47e96_row3_col1, #T_47e96_row4_col0, #T_47e96_row5_col2, #T_47e96_row6_col1, #T_47e96_row7_col0, #T_47e96_row8_col0, #T_47e96_row9_col0, #T_47e96_row10_col0, #T_47e96_row11_col0, #T_47e96_row12_col2, #T_47e96_row13_col2, #T_47e96_row13_col3, #T_47e96_row14_col0 {
#   color: white;
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_47e96_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >folds</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >rows</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47e96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47e96_row0_col0" class="data row0 col0" >0.5510464907</td>
#       <td id="T_47e96_row0_col1" class="data row0 col1" >0.2486642748</td>
#       <td id="T_47e96_row0_col2" class="data row0 col2" >0.2390424758</td>
#       <td id="T_47e96_row0_col3" class="data row0 col3" >0.2669645548</td>
#       <td id="T_47e96_row0_col4" class="data row0 col4" >0.3264294565</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_47e96_row1_col0" class="data row1 col0" >0.8892669082</td>
#       <td id="T_47e96_row1_col1" class="data row1 col1" >1.0000000000</td>
#       <td id="T_47e96_row1_col2" class="data row1 col2" >0.9663894773</td>
#       <td id="T_47e96_row1_col3" class="data row1 col3" >0.6413460970</td>
#       <td id="T_47e96_row1_col4" class="data row1 col4" >0.8742506504</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_47e96_row2_col0" class="data row2 col0" >0.3937512040</td>
#       <td id="T_47e96_row2_col1" class="data row2 col1" >0.2450732291</td>
#       <td id="T_47e96_row2_col2" class="data row2 col2" >0.2352896780</td>
#       <td id="T_47e96_row2_col3" class="data row2 col3" >0.2839302421</td>
#       <td id="T_47e96_row2_col4" class="data row2 col4" >0.2895110846</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_47e96_row3_col0" class="data row3 col0" >0.5258894563</td>
#       <td id="T_47e96_row3_col1" class="data row3 col1" >0.7600160241</td>
#       <td id="T_47e96_row3_col2" class="data row3 col2" >0.4775429666</td>
#       <td id="T_47e96_row3_col3" class="data row3 col3" >0.6382790804</td>
#       <td id="T_47e96_row3_col4" class="data row3 col4" >0.6004319191</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_47e96_row4_col0" class="data row4 col0" >0.5401600599</td>
#       <td id="T_47e96_row4_col1" class="data row4 col1" >0.4998472333</td>
#       <td id="T_47e96_row4_col2" class="data row4 col2" >0.5037006736</td>
#       <td id="T_47e96_row4_col3" class="data row4 col3" >0.5131292939</td>
#       <td id="T_47e96_row4_col4" class="data row4 col4" >0.5142093301</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_47e96_row5_col0" class="data row5 col0" >0.5685969591</td>
#       <td id="T_47e96_row5_col1" class="data row5 col1" >0.6299690008</td>
#       <td id="T_47e96_row5_col2" class="data row5 col2" >0.6370874643</td>
#       <td id="T_47e96_row5_col3" class="data row5 col3" >0.5956205130</td>
#       <td id="T_47e96_row5_col4" class="data row5 col4" >0.6078184843</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_47e96_row6_col0" class="data row6 col0" >0.2696204484</td>
#       <td id="T_47e96_row6_col1" class="data row6 col1" >0.4241000116</td>
#       <td id="T_47e96_row6_col2" class="data row6 col2" >0.2226627618</td>
#       <td id="T_47e96_row6_col3" class="data row6 col3" >0.2376757860</td>
#       <td id="T_47e96_row6_col4" class="data row6 col4" >0.2885147333</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_47e96_row7_col0" class="data row7 col0" >0.4513970912</td>
#       <td id="T_47e96_row7_col1" class="data row7 col1" >0.0021326696</td>
#       <td id="T_47e96_row7_col2" class="data row7 col2" >0.0006830087</td>
#       <td id="T_47e96_row7_col3" class="data row7 col3" >0.0008547530</td>
#       <td id="T_47e96_row7_col4" class="data row7 col4" >0.1137668863</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_47e96_row8_col0" class="data row8 col0" >0.3107537031</td>
#       <td id="T_47e96_row8_col1" class="data row8 col1" >0.2583637238</td>
#       <td id="T_47e96_row8_col2" class="data row8 col2" >0.2570839226</td>
#       <td id="T_47e96_row8_col3" class="data row8 col3" >0.2685575187</td>
#       <td id="T_47e96_row8_col4" class="data row8 col4" >0.2736897171</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_47e96_row9_col0" class="data row9 col0" >0.5489783287</td>
#       <td id="T_47e96_row9_col1" class="data row9 col1" >0.5046707392</td>
#       <td id="T_47e96_row9_col2" class="data row9 col2" >0.4754208326</td>
#       <td id="T_47e96_row9_col3" class="data row9 col3" >0.4691711664</td>
#       <td id="T_47e96_row9_col4" class="data row9 col4" >0.4995602667</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_47e96_row10_col0" class="data row10 col0" >0.5639737844</td>
#       <td id="T_47e96_row10_col1" class="data row10 col1" >0.5154461265</td>
#       <td id="T_47e96_row10_col2" class="data row10 col2" >0.2642332017</td>
#       <td id="T_47e96_row10_col3" class="data row10 col3" >0.4960854053</td>
#       <td id="T_47e96_row10_col4" class="data row10 col4" >0.4599346220</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_47e96_row11_col0" class="data row11 col0" >0.0071080867</td>
#       <td id="T_47e96_row11_col1" class="data row11 col1" >0.0001263511</td>
#       <td id="T_47e96_row11_col2" class="data row11 col2" >0.0067444686</td>
#       <td id="T_47e96_row11_col3" class="data row11 col3" >0.0003954805</td>
#       <td id="T_47e96_row11_col4" class="data row11 col4" >0.0035935966</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_47e96_row12_col0" class="data row12 col0" >0.2316293418</td>
#       <td id="T_47e96_row12_col1" class="data row12 col1" >0.2633186281</td>
#       <td id="T_47e96_row12_col2" class="data row12 col2" >0.2772911787</td>
#       <td id="T_47e96_row12_col3" class="data row12 col3" >0.2429948151</td>
#       <td id="T_47e96_row12_col4" class="data row12 col4" >0.2538084984</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_47e96_row13_col0" class="data row13 col0" >0.9999999404</td>
#       <td id="T_47e96_row13_col1" class="data row13 col1" >0.9947832227</td>
#       <td id="T_47e96_row13_col2" class="data row13 col2" >1.0000000000</td>
#       <td id="T_47e96_row13_col3" class="data row13 col3" >1.0000000000</td>
#       <td id="T_47e96_row13_col4" class="data row13 col4" >0.9986957908</td>
#     </tr>
#     <tr>
#       <th id="T_47e96_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_47e96_row14_col0" class="data row14 col0" >0.2610547543</td>
#       <td id="T_47e96_row14_col1" class="data row14 col1" >0.2556003928</td>
#       <td id="T_47e96_row14_col2" class="data row14 col2" >0.24426

# %%
df.sub(df.mean(axis=1), axis=0) \
    .style.background_gradient(cmap=cm, axis=1)
# Out:
# <style type="text/css">
# #T_47f49_row0_col0, #T_47f49_row1_col1, #T_47f49_row2_col0, #T_47f49_row3_col1, #T_47f49_row4_col0, #T_47f49_row5_col2, #T_47f49_row6_col1, #T_47f49_row7_col0, #T_47f49_row8_col0, #T_47f49_row9_col0, #T_47f49_row10_col0, #T_47f49_row11_col0, #T_47f49_row12_col2, #T_47f49_row13_col0, #T_47f49_row13_col2, #T_47f49_row13_col3, #T_47f49_row14_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_47f49_row0_col1 {
#   background-color: #e4f0e4;
#   color: #000000;
# }
# #T_47f49_row0_col2, #T_47f49_row1_col3, #T_47f49_row2_col2, #T_47f49_row3_col2, #T_47f49_row4_col1, #T_47f49_row5_col0, #T_47f49_row6_col2, #T_47f49_row7_col1, #T_47f49_row7_col2, #T_47f49_row7_col3, #T_47f49_row8_col2, #T_47f49_row9_col3, #T_47f49_row10_col2, #T_47f49_row11_col1, #T_47f49_row12_col0, #T_47f49_row13_col1, #T_47f49_row14_col2 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_47f49_row0_col3 {
#   background-color: #d6e9d6;
#   color: #000000;
# }
# #T_47f49_row1_col0 {
#   background-color: #49a449;
#   color: #f1f1f1;
# }
# #T_47f49_row1_col2 {
#   background-color: #158a15;
#   color: #f1f1f1;
# }
# #T_47f49_row2_col1 {
#   background-color: #ddecdd;
#   color: #000000;
# }
# #T_47f49_row2_col3 {
#   background-color: #a3d0a3;
#   color: #000000;
# }
# #T_47f49_row3_col0 {
#   background-color: #c3e0c3;
#   color: #000000;
# }
# #T_47f49_row3_col3 {
#   background-color: #65b265;
#   color: #f1f1f1;
# }
# #T_47f49_row4_col2 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_47f49_row4_col3 {
#   background-color: #9dcd9d;
#   color: #000000;
# }
# #T_47f49_row5_col1 {
#   background-color: #188c18;
#   color: #f1f1f1;
# }
# #T_47f49_row5_col3 {
#   background-color: #8ec58e;
#   color: #000000;
# }
# #T_47f49_row6_col0 {
#   background-color: #b4d8b4;
#   color: #000000;
# }
# #T_47f49_row6_col3 {
#   background-color: #d9ead9;
#   color: #000000;
# }
# #T_47f49_row8_col1 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_47f49_row8_col3 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_47f49_row9_col1 {
#   background-color: #83c083;
#   color: #000000;
# }
# #T_47f49_row9_col2 {
#   background-color: #d8ead8;
#   color: #000000;
# }
# #T_47f49_row10_col1 {
#   background-color: #269226;
#   color: #f1f1f1;
# }
# #T_47f49_row10_col3 {
#   background-color: #349a34;
#   color: #f1f1f1;
# }
# #T_47f49_row11_col2 {
#   background-color: #0c860c;
#   color: #f1f1f1;
# }
# #T_47f49_row11_col3 {
#   background-color: #e2efe2;
#   color: #000000;
# }
# #T_47f49_row12_col1 {
#   background-color: #48a348;
#   color: #f1f1f1;
# }
# #T_47f49_row12_col3 {
#   background-color: #b1d7b1;
#   color: #000000;
# }
# #T_47f49_row14_col1 {
#   background-color: #4ca54c;
#   color: #f1f1f1;
# }
# #T_47f49_row14_col3 {
#   background-color: #c4e0c4;
#   color: #000000;
# }
# </style>
# <table id="T_47f49_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >folds</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >rows</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47f49_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47f49_row0_col0" class="data row0 col0" >0.2246170342</td>
#       <td id="T_47f49_row0_col1" class="data row0 col1" >-0.0777651817</td>
#       <td id="T_47f49_row0_col2" class="data row0 col2" >-0.0873869807</td>
#       <td id="T_47f49_row0_col3" class="data row0 col3" >-0.0594649017</td>
#     </tr>
#     <tr>
#       <th id="T_47f49_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_47f49_row1_col0" class="data row1 col0" >0.0150162578</td>
#       <td id="T_47f49_row1_col1" class="data row1 col1" >0.1257493496</td>
#       <td id="T_47f49_row1_col2" class="data row1 col2" >0.0921388268</td>
#       <td id="T_47f49_row1_col3" class="data row1 col3" >-0.2329045534</td>
#     </tr>
#     <tr>
#       <th id="T_47f49_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_47f49_row2_col0" class="data row2 col0" >0.1042401195</td>
#       <td id="T_47f49_row2_col1" class="data row2 col1" >-0.0444378555</td>
#       <td id="T_47f49_row2_col2" class="data row2 col2" >-0.0542214066</td>
#       <td id="T_47f49_row2_col3" class="data row2 col3" >-0.0055808425</td>
#     </tr>
#     <tr>
#       <th id="T_47f49_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_47f49_row3_col0" class="data row3 col0" >-0.0745424628</td>
#       <td id="T_47f49_row3_col1" class="data row3 col1" >0.1595841050</td>
#       <td id="T_47f49_row3_col2" class="data row3 col2" >-0.1228889525</td>
#       <td id="T_47f49_row3_col3" class="data row3 col3" >0.0378471613</td>
#     </tr>
#     <tr>
#       <th id="T_47f49_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_47f49_row4_col0" class="data row4 col0" >0.0259507298</td>
#       <td id="T_47f49_row4_col1" class="data row4 col1" >-0.0143620968</td>
#       <td id="T_47f49_row4_col2" class="data row4 col2" >-0.0105086565</td>
#       <td id="T_47f49_row4_col3" class="data row4 col3" >-0.0010800362</td>
#     </tr>
#     <tr>
#       <th id="T_47f49_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_47f49_row5_col0" class="data row5 col0" >-0.0392215252</td>
#       <td id="T_47f49_row5_col1" class="data row5 col1" >0.0221505165</td>
#       <td id="T_47f49_row5_col2" class="data row5 col2" >0.0292689800</td>
#       <td id="T_47f49_row5_col3" class="data row5 col3" >-0.0121979713</td>
#     </tr>
#     <tr>
#       <th id="T_47f49_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_47f49_row6_col0" class="data row6 col0" >-0.0188942850</td>
#       <td id="T_47f49_row6_col1" class="data row6 col1" >0.1355852783</td>
#       <td id="T_47f49_row6_col2" class="data row6 col2" >-0.0658519715</td>
#       <td id="T_47f49_row6_col3" class="data row6 col3" >-0.0508389473</td>
#     </tr>
#     <tr>
#       <th id="T_47f49_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_47f49_row7_col0" class="data row7 col0" >0.3376302123</td>
#       <td id="T_47f49_row7_col1" class="data row7 col1" >-0.1116342172</td>
#       <td id="T_47f49_row7_col2" class="data row7 col2" >-0.1130838767</td>
#       <td id="T_47f49_row7_col3" class="data row7 col3" >-0.1129121333</td>
#     </tr>
#     <tr>
#       <th id="T_47f49_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_47f49_row8_col0" class="data row8 col0" >0.0370639861</td>
#       <td id="T_47f49_row8_col1" class="data row8 col1" >-0.0153259933</td>
#       <td id="T_47f49_row8_col2" class="data row8 col2" >-0.0166057944</td>
#       <td id="T_47f49_row8_col3" class="data row8 col3" >-0.0051321983</td>
#     </tr>
#     <tr>
#       <th id="T_47f49_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_47f49_row9_col0" class="data row9 col0" >0.0494180620</td>
#       <td id="T_47f49_row9_col1" class="data row9 col1" >0.0051104724</td>
#       <td id="T_47f49_row9_col2" class="data row9 col2" >-0.0241394341</td>
#       <td id="T_47f49_row9_col3" class="data row9 col3" >-0.0303891003</td>
#     </tr>
#     <tr>
#       <th id="T_47f49_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_47f49_row10_col0" class="data row10 col0" >0.1040391624</td>
#       <td id="T_47f49_row10_col1" class="data row10 col1" >0.0555115044</td>
#       <td id="T_47f49_row10_col2" class="data row10 col2" >-0.1957014203</td>
#       <td id="T_47f49_row10_col3" class="data row10 col3" >0.0361507833</td>
#     </tr>
#     <tr>
#       <th id="T_47f49_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_47f49_row11_col0" class="data row11 col0" >0.0035144901</td>
#       <td id="T_47f49_row11_col1" class="data row11 col1" >-0.0034672455</td>
#       <td id="T_47f49_row11_col2" class="data row11 col2" >0.0031508720</td>
#       <td id="T_47f49_row11_col3" class="data row11 col3" >-0.0031981161</td>
#     </tr>
#     <tr>
